# %% [markdown]
# <a href="https://colab.research.google.com/github/statsRcool/qr/blob/main/public_qr_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing Dependencies

# %%
# %%capture
! pip install cryptosteganography amzqr Pillow==8.4.0 pyzbar[scripts] 
! apt install libzbar0 
! wget https://raw.githubusercontent.com/statsRcool/qr/main/linkedin_logo.png

# %% [markdown]
# # Linkedin QR Generate
#
# Navigate to your LinkedIn url and copy:
#
#
# ![image Linkedin URL](https://raw.githubusercontent.com/statsRcool/qr/main/linkedin_url.png)

# %%
#@title Enter LinkedIn Handle & QR name (no spaces) { vertical-output: true, form-width: "30%", display-mode: "form" }
handle = "collinparan" #@param {type:"string"}
qr_name = "linkedinqr" #@param {type:"string"}
# !amzqr https://www.linkedin.com/in/{handle}?fromQR=1 -p linkedin_logo.png -c -l Q -n {qr_name}.png

from IPython.display import Image 
Image(f'{qr_name}.png')
# Out:
# line 16: mode: byte
# Succeed!
# Check out your 5-Q QR-code: /content/linkedinqr.png

# %%
# from pyzbar.pyzbar import decode
# from PIL import Image
# decode(Image.open(f'{qr_name}.png'))
