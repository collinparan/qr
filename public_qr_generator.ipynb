# %% [markdown]
# <a href="https://colab.research.google.com/github/statsRcool/qr/blob/main/public_qr_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing Dependencies

# %%
# %%capture
! pip install cryptosteganography amzqr Pillow==8.4.0 pyzbar[scripts] libzbar0

# %% [markdown]
# # Linkedin QR Generate

# %%
#@title Enter LinkedIn Handle & QR name (no spaces) { vertical-output: true, form-width: "50%", display-mode: "form" }
handle = "parannorman" #@param {type:"string"}
qr_name = "linkedinqr" #@param {type:"string"}
# !amzqr https://www.linkedin.com/in/{handle}?fromQR=1 -p linkedin_logo.png -c -l Q -n {qr_name}.png

from IPython.display import Image 
Image(f'{qr_name}.png')
# Out:
# line 16: mode: byte
# Succeed!
# Check out your 5-Q QR-code: /content/linkedinqr.png

# %%
from pyzbar.pyzbar import decode
from PIL import Image
decode(Image.open(f'{qr_name}.png'))
# Out:
# [Decoded(data=b'https://www.linkedin.com/in/parannorman?fromQR=1', type='QRCODE', rect=Rect(left=36, top=36, width=331, height=331), polygon=[Point(x=36, y=36), Point(x=36, y=367), Point(x=367, y=367), Point(x=367, y=36)], quality=1, orientation='UP')]
